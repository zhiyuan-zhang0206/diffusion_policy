# %%
import pickle

path = '/home/zzy/robot/data/robomimic_data/our_robomimic_ph/raw_actions/lift.pkl'

with open(path, 'rb') as f:
    data = pickle.load(f)

print(f'length of data: {len(data)}')
print(f'length of data[0]: {len(data[0])}')
print(f'data[0].shape: {data[0].shape}')
print(f'data[0].dtype: {data[0].dtype}')
print(f'data[0].max(): {data[0].max()}')
print(f'data[0].min(): {data[0].min()}')
print(data[0][:, :3])
# Out:
# length of data: 54
# length of data[0]: 74
# data[0].shape: torch.Size([74, 7])
# data[0].dtype: torch.float32
# data[0].max(): 1.0
# data[0].min(): -1.0
# tensor([[-0.0000,  0.0000,  0.0000],
#         [ 0.2040,  0.0870, -0.0720],
#         [ 0.3230,  0.1310, -0.0730],
#         [ 0.4910,  0.2100, -0.1900],
#         [ 0.4650,  0.3090, -0.3040],
#         [ 0.6030,  0.2780, -0.2580],
#         [ 0.5890,  0.2810, -0.2760],
#         [ 0.6800,  0.3360, -0.2630],
#         [ 0.6190,  0.3620, -0.2630],
#         [ 0.6150,  0.2310, -0.2300],
#         [ 0.5830,  0.1330, -0.3040],
#         [ 0.5620,  0.1410, -0.3280],
#         [ 0.4670,  0.1330, -0.3740],
#         [ 0.5860,  0.1690, -0.4020],
#         [ 0.4820,  0.1090, -0.3970],
#         [ 0.6400,  0.0310, -0.3550],
#         [ 0.4290,  0.1020, -0.3310],
#         [ 0.5790,  0.1060, -0.2880],
#         [ 0.4650,  0.0100, -0.4390],
#         [ 0.5830,  0.1220, -0.4820],
#         [ 0.3880, -0.0070, -0.6300],
# ...
